# %% [markdown]
# # Part 0: Initial setup
#
# To enable GPU:
# 1.   Click Edit -> Notebook settings
# 2.   Under Hardware Accelerator select GPU
# 3.   On the right side of this page, click connect to a hosted runtime
#
#
# If you ever see an error about needing third-party cookies enabled, you can disable blocking them or whitelist them.
# Here is a simple way to whitelist (in chrome)
#
# For old chrome:
# 1.   Goto chrome://settings/content/cookies>search=cookie
# 2.   Uncheck "Block third-party cookies" or
# 3.   Click Add next to Allow and type https://[*.]googleusercontent.com:443
#
# For new chrome:
# 1.   Goto settings and search "cookie"
# 2.   Click the "content settings" button
# 3.   Follow steps 2 or 3 from above
# ---

# %%
# This shows how to connect your google drive account with a colab instance. It's pretty easy.
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/gdrive')
# Create a directory and mount Google Drive using that directory.
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Drive not connecting after it seemed like it worked before?
# 1. First try restarting the runtime via Runtime -> Restart Runtime
# 2. Then try to run the above again.
# 3. If this still doesn't work, call Reset All Runtimes. This is the nuclear option that will delete all your data not saved on your personal drive account, and will erase everything you installed.

# %%
# Now let's test that Google Drive is up and running. 
# You may have to change "My Drive" if you have renamed it something else.
# !ls "/gdrive/My Drive"

with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat "/gdrive/My Drive/foo.txt"
# !rm "/gdrive/My Drive/foo.txt"
# Out:
# '1:1 Meeting.gslides'
#  14.zip
#  2017-01-12-Lab_Partner_Names_not_a_quiz.xls
#  2017-01-12-Lab_Partner_Names_not_a_quiz.xls.gsheet
#  201.zip
# '2D UI in VR User Study Participant Recruitment.gform'
# '2D UI in VR User Study Participant Recruitment (Responses).gsheet'
#  360.pdf
# '3D Painting Tutorial in VR.gslides'
# '590M summary.gslides'
# 'ACM CHI2015 - FlickBoard.mp4'
#  Adobe_intern
# 'ASSETS 2018 Rebuttal - Gesturetag.gdoc'
# 'Basketball video'
# 'Book Review.gdoc'
#  c2857528d4d8ee63e0d5fee915ed0a7d.zip
# "CHI'15-UserDefinedGameInput_Final.zip"
# 'CHI 2018 - RainCheck Rebuttal.gdoc'
# 'CircuitStack Short.mp4'
#  colab_files
# 'Colab Notebooks'
#  convertio.co
# 'Copy of 14.zip'
# 'Copy of 201.zip'
# 'Copy of ZIPLINE-APPLICATION-IRB-Protocol.docx'
# 'CSE475_Hardware Need List.gsheet'
# 'CSE 576 Final Project Proposal.gdoc'
# 'CSE590f_11 15.gslides'
#  CSE590h_Week5.gslides
# 'CSE EE 475 Groups Sign Up.gsheet'
# 'CV HW3 Report.gdoc'
#  CV-YingChao_GAME_internship.pdf
# 'CV-YingChao_Research_internship (1) (1).pdf'
# 'CV-YingChao_Research_internship (1).pdf'
# 'CV-YingChao_Research_internship (2).pdf'
#  CV-YingChao_Research_internship.pdf
# 'CV-YingChao_SWE_internship (1) (1).pdf'
# 'CV-YingChao_SWE_internship (1).pdf'
#  CV-YingChao_SWE_internship_2018ms_s.pdf
#  CV-YingChao_SWE_internship_2018s.pdf
# 'CV-YingChao_SWE_internship (2).pdf'
#  CV-YingChao_SWE_internship.pdf
#  data.gsheet
# 'Drawing in VR Study Schedule.gform'
# 'Draw Some Toast- The arcade that lets you draw toasts with jam.mp4'
#  dub_retreat_poster.pdf
#  EE511_Presentation_v6.pdf
#  EE511_Presentation_v7.pdf
#  ENTRE510_Game_CoLab.gdoc
# 'ENTRE 510 HW1.gdoc'
#  ENTRE510_Lit_Motors.gdoc
#  ENTRE510_RTR.gdoc
# 'ENTRE 510_Uber.gdoc'
#  ENTRE_LinkedIn.gdoc
# 'ENTRE_MOD Pizza.gdoc'
#  ENTRE_SenseGiz.gdoc
#  Gazereport_button_data.csv
# 'Gaze_report_slider_data (1).csv'
#  Gaze_report_slider_data.csv
#  Gaze_report_slider_data.json
# 'Glacier-Employee-Training-Guide (8).docx'
#  Handreport_button_data.csv
#  Hand_report_slider_data.csv
#  In_Air_Touch_Worldreport_button_data.csv
#  In_Air_Touch_World_report_slider_data.csv
# "IndieCade'14_Transection.mp4"
#  Mousereport_button_data.csv
#  Mouse_report_slider_data.csv
# 'Mute Robot- Cooperative Gameplay through Body Language Communication.mp4'
# 'New employee on-line forms - FN (12).doc'
# 'New house furniture bill.gsheet'
#  new_res.json
# 'NLP Final'
# 'NLP HW5.gdoc'
# 'NO trip.gsheet'
#  Offer_Document_Ying-Chao_Tung.pdf
#  prj-GestureTag
#  prj-POPVR
#  prj-sketchVR
# 'proposed_study_final (1).docx.gdoc'
#  proposed_study_final.docx
#  proposed_study_final.docx.gdoc
#  Public_Test
#  RainCheck
# 'RainCheck - ICMI 2018 Rebuttal.gdoc'
#  RainCheck_Rebuttal_draft.gdoc
#  RainCheck_Rebuttal_draft-jw.docx
#  RainCheck_Rebuttal_draft-tony3.gdoc
#  RainCheck_Rebuttal_draft-tony3-jw.docx
#  RainCheck_Rebuttal_draft-tony3-jw.docx.gdoc
# 'RainCheck Reviewer Concerns.gdoc'
#  rainchecksheet.xlsx
#  raincheck_w.csv
#  raincheck_w_sl.gsheet
#  Ray_Castingreport_button_data.csv
#  Ray_Casting_report_slider_data.csv
#  Rental-Application.doc
#  Rental-Application.doc.gdoc
#  resume-YingChao_SWE_2019.pdf
# 'Seattle food map.gmap'
#  selfiesensei_poster.pdf
#  SketchVR.gslides
#  sleep_stage_classifier.pptx
#  sleep_stage_classifier.pptx.gslides
#  Surfing_20180826
#  Tablereport_button_data.csv
#  Table_report_slider_data.csv
#  TouchSense.mp4
#  TUNGYING-CHAO1062016TaxDocs.pdf
# 'Tung, Ying-Chao.docx'
# 'TungY_Intern - signed.pdf'
# 'UIST 2017 RainCheck Rebuttal.gdoc'
# 'Untitled document.gdoc'
# 'Untitled form.gform'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'VRUI Study 2 Participant Recruitment.gform'
# 'VRUI Study Interview .gform'
# 'VRUI Study Interview  (Responses).gsheet'
# 'VRUI Study I Questionnaire.gform'
# 'VRUI Study I Questionnaire (Responses).gsheet'
# 'VRUI User Study 2 Questionnaire.gform'
#  YingChao_VR_internship_2018ms.pdf
#  ZIPLINE-APPLICATION-IRB-Protocol.gdoc
#  阿里山
# Hello Google Drive!

# %%
# This is code to download and install pytorch
from os import path
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
  
import torch
print('Version', torch.__version__)
print('CUDA enabled:', torch.cuda.is_available())
  
# NOTE: This one takes a while the first time you run it, and you will likely see 
# tcmalloc: large alloc 1073750016 bytes == 0x5c54a000 @ or something similar.
# It should then print out:
# Version 0.4.1
# CUDA enabled: True
# Out:
# Version 0.4.1
# CUDA enabled: True

# %%
# Define some useful save and restoring functions. 
# You can thank your TAs for providing this code, 
# it will probably be useful for you in the future as well.
import torch
import torch.nn as nn
import numpy as np
import os
class pt_util(object):
    @staticmethod
    # This does more than the simple Pytorch restore. It checks that the names 
    # of variables match, and if they don't doesn't throw a fit. It is similar 
    # to how Caffe acts. This is especially useful if you decide to change your
    # network architecture but don't want to retrain from scratch.
    def restore(net, save_file):
        net_state_dict = net.state_dict()
        restore_state_dict = torch.load(save_file)

        restored_var_names = set()

        print('Restoring:')
        for var_name in restore_state_dict.keys():
            if var_name in net_state_dict:
                var_size = net_state_dict[var_name].size()
                restore_size = restore_state_dict[var_name].size()
                if var_size != restore_size:
                    print('Shape mismatch for var', var_name, 'expected', var_size, 'got', restore_size)
                else:
                    if isinstance(net_state_dict[var_name], torch.nn.Parameter):
                        # backwards compatibility for serialized parameters
                        net_state_dict[var_name] = restore_state_dict[var_name].data
                    try:
                        net_state_dict[var_name].copy_(restore_state_dict[var_name])
                        print(str(var_name) + ' -> \t' + str(var_size) + ' = ' + str(int(np.prod(var_size) * 4 / 10**6)) + 'MB')
                        restored_var_names.add(var_name)
                    except:
                        print('While copying the parameter named {}, whose dimensions in the model are'
                              ' {} and whose dimensions in the checkpoint are {}, ...'.format(
                                  var_name, var_size, restore_size))
                        raise

        ignored_var_names = sorted(list(set(restore_state_dict.keys()) - restored_var_names))
        unset_var_names = sorted(list(set(net_state_dict.keys()) - restored_var_names))
        print('')
        if len(ignored_var_names) == 0:
            print('Restored all variables')
        else:
            print('Did not restore:\n\t' + '\n\t'.join(ignored_var_names))
        if len(unset_var_names) == 0:
            print('No new variables')
        else:
            print('Initialized but did not modify:\n\t' + '\n\t'.join(unset_var_names))

        print('Restored %s' % save_file)
        
    @staticmethod
    def restore_latest(net, folder):
        import glob
        import re
        checkpoints = sorted(glob.glob(folder + '/*.pt'), key=os.path.getmtime)
        start_it = 0
        if len(checkpoints) > 0:
            pt_util.restore(net, checkpoints[-1])
            start_it = int(re.findall(r'\d+', checkpoints[-1])[-1])
        return start_it

    @staticmethod
    def save(net, file_name, num_to_keep=1):
        folder = os.path.dirname(file_name)
        if not os.path.exists(folder):
            os.makedirs(folder)
        torch.save(net.state_dict(), file_name)
        import glob
        extension = os.path.splitext(file_name)[1]
        checkpoints = sorted(glob.glob(folder + '/*' + extension), key=os.path.getmtime)
        print('Saved %s\n' % file_name)
        if num_to_keep > 0:
            for ff in checkpoints[:-num_to_keep]:
                os.remove(ff)

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl torchvision
import torch

# %% [markdown]
# # Part 1: Implementing a network for MNIST

# %%
# This is where you define your network architecture.
# Note: The TAs know this follows the PyTorch MNIST tutorial available at 
# https://github.com/pytorch/examples/blob/master/mnist/main.py
# Where do you think we got it from? 
# So we are asking you to implement something slightly different. 
# You can use that as a guide, but make sure you understand what it all does.


import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
class MNISTNet(nn.Module):
    def __init__(self):
        super(MNISTNet, self).__init__()
        
        # The network should be as follows:
        # One fully connected layer with 1024 outputs.
        # One fully connected layer with 512 outputs.
        self.fc1 = nn.Linear(28 * 28, 1024)
        self.fc2 = nn.Linear(1024, 512)
        # Then the final classification layer.
        self.fc = nn.Linear(512, 10)
        # All the nonlinearities should be ReLU.
        # These instructions are vague on purpose.
        # raise NotImplementedError('Define the layers here')

    def forward(self, x):
        #raise NotImplementedError('Define the forward pass')
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc(x)
        return x
        
    def save_model(self, file_path, num_to_keep=1):
        pt_util.save(self, file_path, num_to_keep)
        
    def loss(self, prediction, label, reduction='elementwise_mean'):
        # You should also use the cross_entropy loss rather than the NLL loss.
        # raise NotImplementedError('Define the loss here')
        criterion = nn.CrossEntropyLoss(reduction=reduction)
        return criterion(prediction, label)

    def load_model(self, file_path):
        pt_util.restore(self, file_path)

    def load_last_model(self, dir_path):
        return pt_util.restore_latest(self, dir_path)


def train(model, device, train_loader, optimizer, epoch, log_interval):
    model.train()
    for batch_idx, (data, label) in enumerate(train_loader):
        data, label = data.to(device), label.to(device)
        optimizer.zero_grad()
        #raise NotImplementedError('Define the forward pass and loss here')
        data = data.view(-1, 28 * 28)
        outputs = model(data)
        loss = model.loss(outputs, label)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

def test(model, device, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, label in test_loader:
            data, label = data.to(device), label.to(device)
            data = data.view(-1, 28 * 28)
            output = model(data)
            test_loss += model.loss(output, label, reduction='elementwise_mean').item()
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(label.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
# Play around with these constants, you may find a better setting.
BATCH_SIZE = 256
TEST_BATCH_SIZE = 1000
EPOCHS = 10
LEARNING_RATE = 0.01
MOMENTUM = 0.5
USE_CUDA = True
SEED = 0
LOG_INTERVAL = 100

# %%
# Now the actual training code
use_cuda = USE_CUDA and torch.cuda.is_available()

torch.manual_seed(SEED)

device = torch.device("cuda" if use_cuda else "cpu")
print('Using device', device)
import multiprocessing
print('num cpus:', multiprocessing.cpu_count())

kwargs = {'num_workers': multiprocessing.cpu_count(),
          'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=TEST_BATCH_SIZE, **kwargs)


model = MNISTNet().to(device)
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
# This will save checkpoints in your Google Drive account.
start_epoch = model.load_last_model('/gdrive/My Drive/colab_files/homework1/mnist/checkpoints')
try:
    for epoch in range(start_epoch, EPOCHS + 1):
        print('training started')
        train(model, device, train_loader, optimizer, epoch, LOG_INTERVAL)
        print('training finished')
        print('-------------------')
        print('testing started')
        test(model, device, test_loader)
        model.save_model('/gdrive/My Drive/colab_files/homework1/mnist/checkpoints/%03d.pt' % epoch)
except KeyboardInterrupt as ke:
    print('Interrupted')
except:
    import traceback
    traceback.print_exc()
finally:
    model.save_model('/gdrive/My Drive/colab_files/homework1/mnist/checkpoints/%03d.pt' % epoch)
# Out:
# Using device cuda
# num cpus: 2
# training started
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.303680
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.888739
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.494682
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0004, Accuracy: 8907/10000 (89%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/000.pt
#
# training started
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.365670
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.379488
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.348191
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0003, Accuracy: 9130/10000 (91%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/001.pt
#
# training started
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.306433
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.339676
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.267423
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0003, Accuracy: 9227/10000 (92%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/002.pt
#
# training started
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.248521
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.301778
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.239206
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0002, Accuracy: 9290/10000 (93%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/003.pt
#
# training started
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.289494
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.221331
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.272640
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0002, Accuracy: 9367/10000 (94%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/004.pt
#
# training started
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.227347
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.210748
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.255568
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0002, Accuracy: 9412/10000 (94%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/005.pt
#
# training started
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.296914
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.298284
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.192674
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0002, Accuracy: 9462/10000 (95%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/006.pt
#
# training started
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.182288
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.171527
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.191305
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0002, Accuracy: 9499/10000 (95%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/007.pt
#
# training started
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.188793
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.134135
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.166674
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0002, Accuracy: 9514/10000 (95%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/008.pt
#
# training started
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.165933
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.146951
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.114934
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0002, Accuracy: 9554/10000 (96%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/009.pt
#
# training started
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.121409
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.145694
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.111522
# training finished
# -------------------
# testing started
#
# Test set: Average loss: 0.0001, Accuracy: 9559/10000 (96%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/010.pt
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist/checkpoints/010.pt

# %% [markdown]
# # Part 2: Reimplementing the Cross Entropy loss function.

# %%
class MNISTNetNewLoss(MNISTNet):
  
    def loss(self, prediction, label, reduction='elementwise_mean'): 
        # Reimplement the Cross Entropy loss function using mathematical primitives.
        # This means you are not allowed to use any function in the "Loss functions" 
        # section of https://pytorch.org/docs/stable/nn.html#id50 nor the 
        # functional versions. You can use them to verify that your output looks correct.
        # You should implement reduction for none (i.e. return a vector, sum, and elementwise_mean).
        # Note: Due to floating point errors, the values won't be exactly equal.
        # Second note: You can assume inputs will be 2D (batch X features).
        loss_val_old = super(MNISTNetNewLoss, self).loss(prediction, label, reduction)        
        m = label.shape[0]
        # prediction: 256 x 10
        # label: 256 x 1
        loss_val_new = -prediction[[torch.arange(m), label]] + torch.log(torch.sum(torch.exp(prediction), 1))
        
        if reduction == 'elementwise_mean':
            loss_val_new = torch.mean(loss_val_new)
            assert(abs(loss_val_new - loss_val_old).item() < 0.01)
        elif reduction == 'sum':
            loss_val_new = torch.sum(loss_val_new)
        
        return loss_val_new

# %%
# Now the actual training code
use_cuda = USE_CUDA and torch.cuda.is_available()

torch.manual_seed(SEED)

device = torch.device("cuda" if use_cuda else "cpu")
print('Using device', device)
import multiprocessing
print('num cpus:', multiprocessing.cpu_count())

kwargs = {'num_workers': multiprocessing.cpu_count(),
          'pin_memory': True} if use_cuda else {}
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../data', train=False, transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.1307,), (0.3081,))
                   ])),
    batch_size=TEST_BATCH_SIZE, **kwargs)


model = MNISTNetNewLoss().to(device)
optimizer = optim.SGD(model.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM)
start_epoch = model.load_last_model('/gdrive/My Drive/colab_files/homework1/mnist2/checkpoints')
try:
    for epoch in range(start_epoch, EPOCHS + 1):
        train(model, device, train_loader, optimizer, epoch, LOG_INTERVAL)
        test(model, device, test_loader)
        model.save_model('/gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/%03d.pt' % epoch)
except KeyboardInterrupt as ke:
    print('Interrupted')
except:
    import traceback
    traceback.print_exc()
finally:
    model.save_model('/gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/%03d.pt' % epoch)
# Out:
# Using device cuda
# num cpus: 2
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.303680
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 0.888741
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.494680
#
# Test set: Average loss: 0.0004, Accuracy: 8907/10000 (89%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/000.pt
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.365670
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.379490
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.348167
#
# Test set: Average loss: 0.0003, Accuracy: 9130/10000 (91%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/001.pt
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.306437
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.339680
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.267435
#
# Test set: Average loss: 0.0003, Accuracy: 9228/10000 (92%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/002.pt
#
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.248540
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.301812
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.239199
#
# Test set: Average loss: 0.0002, Accuracy: 9291/10000 (93%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/003.pt
#
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.289475
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.221326
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.272655
#
# Test set: Average loss: 0.0002, Accuracy: 9367/10000 (94%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/004.pt
#
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.227357
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.210724
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.255594
#
# Test set: Average loss: 0.0002, Accuracy: 9413/10000 (94%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/005.pt
#
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.296861
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.298260
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.192634
#
# Test set: Average loss: 0.0002, Accuracy: 9462/10000 (95%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/006.pt
#
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.182246
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.171570
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.191295
#
# Test set: Average loss: 0.0002, Accuracy: 9500/10000 (95%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/007.pt
#
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.188739
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.134154
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.166723
#
# Test set: Average loss: 0.0002, Accuracy: 9514/10000 (95%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/008.pt
#
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.165912
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.146911
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.114854
#
# Test set: Average loss: 0.0002, Accuracy: 9553/10000 (96%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/009.pt
#
# Train Epoch: 10 [0/60000 (0%)]	Loss: 0.121347
# Train Epoch: 10 [25600/60000 (43%)]	Loss: 0.145681
# Train Epoch: 10 [51200/60000 (85%)]	Loss: 0.111495
#
# Test set: Average loss: 0.0001, Accuracy: 9561/10000 (96%)
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/010.pt
#
# Saved /gdrive/My Drive/colab_files/homework1/mnist2/checkpoints/010.pt
